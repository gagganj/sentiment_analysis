# %%
import numpy as np
import pandas as pd
import random as rn
import sklearn
from sklearn import metrics
#import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.inspection import PartialDependenceDisplay
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics # Import scikit-learn metrics module for accuracy calculation
from sklearn import preprocessing # Import preprocessing for String-Int conversion
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Load in the dictionary dataset into a pandas df
data_path = os.path.join(os.getcwd(), 'data', 'dictionary.txt')
dic = pd.read_csv(data_path, sep='|', header=None)

# ...and do the same with the sentiment_labels data
data_path = os.path.join(os.getcwd(), 'data', 'sentiment_labels.txt')
cents = pd.read_csv(data_path, sep='|')

dic = dic.rename(columns={0: "feature", 1: "ID"}) # We rename the columns
dic = dic.sort_values(by="ID") # We change the order of the rows to be sorted by ID number
movie_data = dic[["ID", "feature"]] # We change the order of the columns and change the name of the the df

# We make an array of the sentiments (already in the right order) and add it to our df
y = np.array(cents.iloc[:, -1])
movie_data.insert(2, "sentiment", y)

print(movie_data.head())
# Out:
#     ID              feature  sentiment
# 0    0                    !    0.50000
# 65   1                    '    0.50000
# 66   2                  ' (    0.44444
# 70   3    ' ( the cockettes    0.50000
# 71   4  ' ( the cockettes )    0.42708

# %%
print(movie_data["sentiment"][65])
# Out:
# 0.5

# %%
#data preprossing

# 1) relabel sentiment with corresponding category + drop sentiment column
# 2) one hot encode these 5 catecories
# 3)'clean' phrases: remove numbers, punctuation and filler words
# 4) convert phrases to numerical representation: bag of words?
# 5) remove empty processed prases and drop duplicates

#1)
#values =[[0, 0.2], [0.2, 0.4], [0.4, 0.6], [0.6, 0.8], [0.8, 1.0]]
labels = ['very negative', 'negative', 'neutral', 'positive', 'very positive']

movie_data.insert(3,"label",'none')

for i in range (movie_data.shape[0]):
    if (movie_data["sentiment"][i]<=0.2):
        movie_data["label"][i]=labels[0]
    if (movie_data["sentiment"][i]>0.2) and (movie_data["sentiment"][i]<=0.4):
        movie_data["label"][i]=labels[1]
    if (movie_data["sentiment"][i]>0.4) and (movie_data["sentiment"][i]<=0.6):
        movie_data["label"][i]=labels[2]
    if (movie_data["sentiment"][i]>0.6) and (movie_data["sentiment"][i]<=0.8):
        movie_data["label"][i]=labels[3]
    if (movie_data["sentiment"][i]>0.8) and (movie_data["sentiment"][i]<=1):
        movie_data["label"][i]=labels[4]
    #print(i,movie_data["label"][i],)

print(movie_data.head())

movie_data.drop("sentiment")

#2)


#5)
#movie_data.drop_duplicates()

#save this as file - takes ages to complete
# Out:
# <ipython-input-17-f73203f3e0f5>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data["label"][i]=labels[2]
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-17-f73203f3e0f5>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data["label"][i]=labels[4]
# <ipython-input-17-f73203f3e0f5>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data["label"][i]=labels[3]
# <ipython-input-17-f73203f3e0f5>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data["label"][i]=labels[1]
# <ipython-input-17-f73203f3e0f5>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_data["label"][i]=labels[0]
# 0 neutral
# 1 neutral
# 2 neutral
# 3 neutral
# 4 very positive
# 5 very positive
# 6 very positive
# 7 neutral
# 8 positive
# 9 negative
# 10 neutral
# 11 neutral
# 12 neutral
# 13 negative
# 14 neutral
# 15 positive
# 16 positive
# 17 neutral
# 18 neutral
# 19 neutral
# 20 neutral
# 21 neutral
# 22 neutral
# 23 neutral
# 24 neutral
# 25 neutral
# 26 neutral
# 27 neutral
# 28 neutral
# 29 neutral
# 30 positive
# 31 neutral
# 32 neutral
# 33 positive
# 34 neutral
# 35 neutral
# 36 neutral
# 37 neutral
# 38 neutral
# 39 neutral
# 40 neutral
# 41 neutral
# 42 neutral
# 43 neutral
# 44 neutral
# 45 neutral
# 46 neutral
# 47 very negative
# 48 neutral
# 49 neutral
# 50 negative
# 51 neutral
# 52 neutral
# 53 neutral
# 54 negative
# 55 negative
# 56 negative
# 57 negative
# 58 positive
# 59 neutral
# 60 neutral
# 61 positive
# 62 neutral
# 63 positive
# 64 neutral
# 65 neutral
# 66 neutral
# 67 neutral
# 68 negative
# 69 positive
# 70 neutral
# 71 neutral
# 72 negative
# 73 neutral
# 74 neutral
# 75 neutral
# 76 positive
# 77 neutral
# 78 positive
# 79 very positive
# 80 positive
# 81 very positive
# 82 neutral
# 83 negative
# 84 very positive
# 85 neutral
# 86 neutral
# 87 positive
# 88 negative
# 89 negative
# 90 neutral
# 91 neutral
# 92 neutral
# 93 neutral
# 94 neutral
# 95 neutral
# 96 positive
# 97 neutral
# 98 neutral
# 99 neutral
# 100 negative
# 101 neutral
# 102 neutral
# 103 neutral
# 104 negative
# 105 very positive
# 106 very positive
# 107 very positive
# 108 positive
# 109 neutral
# 110 neutral
# 111 neutral
# 112 positive
# 113 neutral
# 114 neutral
# 115 neutral
# 116 positive
# 117 positive
# 118 positive
# 119 neutral
# 120 neutral
# 121 negative
# 122 neutral
# 123 neutral
# 124 negative
# 125 neutral
# 126 neutral
# 127 neutral
# 128 neutral
# 129 neutral
# 130 negative
# 131 neutral
# 132 neutral
# 133 neutral
# 134 negative
# 135 neutral
# 136 neutral
# 137 negative
# 138 neutral
# 139 very negative
# 140 negative
# 141 neutral
# 142 neutral
# 143 positive
# 144 neutral
# 145 neutral
# 146 positive
# 147 negative
# 148 neutral
# 149 very negative
# 150 neutral
# 151 neutral
# 152 neutral
# 153 neutral
# 154 neutral
# 155 neutral
# 156 neutral
# 157 neutral
# 158 neutral
# 159 very negative
# 160 positive
# 161 neutral
# 162 neutral
# 163 neutral
# 164 very negative
# 165 neutral
# 166 very positive
# 167 positive
# 168 neutral
# 169 neutral
# 170 neutral
# 171 neutral
# 172 positive
# 173 negative
# 174 neutral
# 175 neutral
# 176 negative
# 177 negative
# 178 neutral
# 179 neutral
# 180 neutral
# 181 neutral
# 182 neutral
# 183 very negative
# 184 neutral
# 185 neutral
# 186 neutral
# 187 negative
# 188 neutral
# 189 neutral
# 190 very positive
# 191 negative
# 192 negative
# 193 neutral
# 194 positive
# 195 very negative
# 196 positive
# 197 neutral
# 198 very negative
# 199 positive
# 200 positive
# 201 positive
# 202 very negative
# 203 neutral
# 204 neutral
# 205 positive
# 206 neutral
# 207 neutral
# 208 positive
# 209 positive
# 210 neutral
# 211 positive
# 212 very positive
# 213 neutral
# 214 neutral
# 215 neutral
# 216 negative
# 217 neutral
# 218 positive
# 219 negative
# 220 neutral
# 221 very positive
# 222 negative
# 223 very positive
# 224 neutral
# 225 neutral
# 226 very positive
# 227 neutral
# 228 neutral
# 229 neutral
# 230 negative
# 231 neutral
# 232 negative
# 233 positive
# 234 neutral
# 235 very positive
# 236 neutral
# 237 neutral
# 238 neutral
# 239 negative
# 240 neutral
# 241 negative
# 242 neutral
# 243 neutral
# 244 neutral
# 245 neutral
# 246 negative
# 247 neutral
# 248 very positive
# 249 neutral
# 250 positive
# 251 negative
# 252 positive
# 253 positive
# 254 positive
# 255 negative
# 256 negative
# 257 neutral
# 258 neutral
# 259 positive
# 260 positive
# 261 positive
# 262 neutral
# 263 positive
# 264 neutral
# 265 neutral
# 266 neutral
# 267 neutral
# 268 neutral
# 269 neutral
# 270 neutral
# 271 negative
# 272 positive
# 273 neutral
# 274 positive
# 275 neutral
# 276 neutral
# 277 neutral
# 278 neutral
# 279 neutral
# 280 neutral
# 281 neutral
# 282 neutral
# 283 neutral
# 284 neutral
# 285 neutral
# 286 positive
# 287 neutral
# 288 neutral
# 289 positive
# 290 negative
# 291 neutral
# 292 neutral
# 293 neutral
# 294 negative
# 295 neutral
# 296 neutral
# 297 positive
# 298 positive
# 299 very positive
# 300 neutral
# 301 neutral
# 302 neutral
# 303 neutral
# 304 very negative
# 305 neutral
# 306 very positive
# 307 neutral
# 308 neutral
# 309 positive
# 310 neutral
# 311 neutral
# 312 negative
# 313 neutral
# 314 negative
# 315 negative
# 316 neutral
# 317 neutral
# 318 neutral
# 319 positive
# 320 neutral
# 321 neutral
# 322 neutral
# 323 very negative
# 324 neutral
# 325 positive
# 326 neutral
# 327 very negative
# 328 very positive
# 329 neutral
# 330 neutral
# 331 neutral
# 332 neutral
# 333 positive
# 334 neutral
# 335 neutral
# 336 neutral
# 337 neutral
# 338 very positive
# 339 positive
# 340 neutral
# 341 positive
# 342 neutral
# 343 neutral
# 344 neutral
# 345 neutral
# 346 neutral
# 347 negative
# 348 neutral
# 349 neutral
# 350 negative
# 351 negative
# 352 neutral
# 353 neutral
# 354 positive
# 355 very positive
# 356 neutral
# 357 neutral
# 358 positive
# 359 neutral
# 360 neutral
# 361 neutral
# 362 neutral
# 363 positive
# 364 very positive
# 365 negative
# 366 neutral
# 367 neutral
# 368 very positive
# 369 very negative
# 370 positive
# 371 positive
# 372 negative
# 373 neutral
# 374 positive
# 375 neutral
# 376 neutral
# 377 very positive
# 378 positive
# 379 neutral
# 380 negative
# 381 neutral
# 382 neutral
# 383 very negative
# 384 positive
# 385 very positive
# 386 positive
# 387 neutral
# 388 positive
# 389 very positive
# 390 very positive
# 391 positive
# 392 very negative
# 393 very positive
# 394 positive
# 395 positive
# 396 positive
# 397 very negative
# 398 very positive
# 399 very positive
# 400 positive
# 401 positive
# 402 positive
# 403 very positive
# 404 positive
# 405 positive
# 406 neutral
# 407 neutral
# 408 positive
# 409 negative
# 410 very negative
# 411 positive
# 412 positive
# 413 neutral
# 414 positive
# 415 positive
# 416 positive
# 417 very positive
# 418 neutral
# 419 negative
# 420 neutral
# 421 negative
# 422 positive
# 423 negative
# 424 negative
# 425 neutral
# 426 neutral
# 427 neutral
# 428 negative
# 429 positive
# 430 positive
# 431 neutral
# 432 neutral
# 433 negative
# 434 very negative
# 435 very positive
# 436 very positive
# 437 neutral
# 438 neutral
# 439 neutral
# 440 neutral
# 441 positive
# 442 neutral
# 443 neutral
# 444 negative
# 445 positive
# 446 very negative
# 447 neutral
# 448 negative
# 449 positive
# 450 neutral
# 451 neutral
# 452 positive
# 453 neutral
# 454 neutral
# 455 neutral
# 456 positive
# 457 neutral
# 458 positive
# 459 neutral
# 460 positive
# 461 neutral
# 462 neutral
# 463 neutral
# 464 neutral
# 465 neutral
# 466 negative
# 467 neutral
# 468 neutral
# 469 neutral
# 470 negative
# 471 negative
# 472 negative
# 473 positive
# 474 positive
# 475 negative
# 476 positive
# 477 neutral
# 478 very negative
# 479 very positive
# 480 neutral
# 481 neutral
# 482 neutral
# 483 neutral
# 484 very negative
# 485 neutral
# 486 very positive
# 487 negative
# 488 neutral
# 489 neutral
# 490 neutral
# 491 positive
# 492 neutral
# 493 neutral
# 494 neutral
# 495 negative
# 496 neutral
# 497 neutral
# 498 very negative
# 499 negative
# 500 neutral
# 501 neutral
# 502 neutral
# 503 very negative
# 504 positive
# 505 neutral
# 506 positive
# 507 neutral
# 508 very positive
# 509 neutral
# 510 neutral
# 511 neutral
# 512 neutral
# 513 neutral
# 514 neutral
# 515 neutral
# 516 neutral
# 517 neutral
# 518 neutral
# 519 neutral
# 520 neutral
# 521 neutral
# 522 neutral
# 523 neutral
# 524 neutral
# 525 neutral
# 526 positive
# 527 neutral
# 528 neutral
# 529 neutral
# 530 neutral
# 531 neutral
# 532 neutral
# 533 neutral
# 534 neutral
# 535 neutral
# 536 neutral
# 537 neutral
# 538 neutral
# 539 neutral
# 540 neutral
# 541 neutral
# 542 neutral
# 543 neutral
# 544 neutral
# 545 neutral
# 546 neutral
# 547 neutral
# 548 neutral
# 549 negative
# 550 negative
# 551 negative
# 552 neutral
# 553 neutral
# 554 positive
# 555 positive
# 556 positive
# 557 neutral
# 558 negative
# 559 neutral
# 560 neutral
# 561 negative
# 562 neutral
# 563 neutral
# 564 neutral
# 565 neutral
# 566 neutral
# 567 negative
# 568 positive
# 569 positive
# 570 neutral
# 571 neutral
# 572 neutral
# 573 neutral
# 574 neutral
# 575 neutral
# 576 neutral
# 577 neutral
# 578 positive
# 579 neutral
# 580 neutral
# 581 neutral
# 582 neutral
# 583 negative
# 584 very negative
# 585 positive
# 586 positive
# 587 very negative
# 588 negative
# 589 neutral
# 590 neutral
# 591 neutral
# 592 positive
# 593 very positive
# 594 negative
# 595 neutral
# 596 neutral
# 597 negative
# 598 positive
# 599 neutral
# 600 neutral
# 601 neutral
# 602 positive
# 603 neutral
# 604 negative
# 605 negative
# 606 neutral
# 607 neutral
# 608 neutral
# 609 negative
# 610 neutral
# 611 neutral
# 612 negative
# 613 negative
# 614 neutral
# 615 negative
# 616 negative
# 617 neutral
# 618 very negative
# 619 negative
# 620 negative
# 621 negative
# 622 neutral
# 623 neutral
# 624 neutral
# 625 neutral
# 626 neutral
# 627 neutral
# 628 neutral
# 629 positive
# 630 very positive
# 631 neutral
# 632 neutral
# 633 positive
# 634 positive
# 635 neutral
# 636 negative
# 637 neutral
# 638 negative
# 639 neutral
# 640 negative
# 641 very negative
# 642 very negative
# 643 neutral
# 644 neutral
# 645 neutral
# 646 positive
# 647 positive
# 648 positive
# 649 neutral
# 650 neutral
# 651 positive
# 652 neutral
# 653 neutral
# 654 neutral
# 655 positive
# 656 positive
# 657 neutral
# 658 neutral
# 659 neutral
# 660 very negative
# 661 very negative
# 662 very negative
# 663 negative
# 664 neutral
# 665 positive
# 666 positive
# 667 negative
# 668 very negative
# 669 negative
# 670 very positive
# 671 very positive
# 672 neutral
# 673 negative
# 674 very negative
# 675 very negative
# 676 neutral
# 677 neutral
# 678 neutral
# 679 positive
# 680 very positive
# 681 neutral
# 682 negative
# 683 neutral
# 684 very negative
# 685 very negative
# 686 neutral
# 687 negative
# 688 positive
# 689 positive
# 690 very positive
# 691 positive
# 692 negative
# 693 negative
# 694 positive
# 695 neutral
# 696 neutral
# 697 neutral
# 698 neutral
# 699 negative
# 700 negative
# 701 neutral
# 702 neutral
# 703 neutral
# 704 positive
# 705 neutral
# 706 very positive
# 707 very positive
# 708 positive
# 709 positive
# 710 neutral
# 711 positive
# 712 neutral
# 713 negative
# 714 very negative
# 715 positive
# 716 very positive
# 717 positive
# 718 very negative
# 719 positive
# 720 neutral
# 721 neutral
# 722 positive
# 723 neutral
# 724 neutral
# 725 positive
# 726 positive
# 727 positive
# 728 positive
# 729 neutral
# 730 neutral
# 731 neutral
# 732 neutral
# 733 neutral
# 734 neutral
# 735 neutral
# 736 negative
# 737 negative
# 738 neutral
# 739 negative
# 740 neutral
# 741 negative
# 742 neutral
# 743 positive
# 744 negative
# 745 neutral
# 746 negative
# 747 negative
# 748 negative
# 749 positive
# 750 negative
# 751 negative
# 752 positive
# 753 neutral
# 754 very positive
# 755 positive
# 756 very negative
# 757 negative
# 758 negative
# 759 neutral
# 760 neutral
# 761 very positive
# 762 very positive
# 763 neutral
# 764 neutral
# 765 neutral
# 766 neutral
# 767 neutral
# 768 negative
# 769 neutral
# 770 neutral
# 771 neutral
# 772 neutral
# 773 positive
# 774 positive
# 775 positive
# 776 very negative
# 777 negative
# 778 very negative
# 779 negative
# 780 neutral
# 781 very negative
# 782 neutral
# 783 positive
# 784 very positive
# 785 positive
# 786 neutral
# 787 positive
# 788 neutral
# 789 positive
# 790 positive
# 791 neutral
# 792 positive
# 793 positive
# 794 negative
# 795 neutral
# 796 neutral
# 797 neutral
# 798 neutral
# 799 positive
# 800 neutral
# 801 neutral
# 802 neutral
# 803 very positive
# 804 very positive
# 805 very positive
# 806 very positive
# 807 very positive
# 808 very positive
# 809 very positive
# 810 very positive
# 811 positive
# 812 negative
# 813 neutral
# 814 neutral
# 815 neutral
# 816 neutral
# 817 neutral
# 818 neutral
# 819 very negative
# 820 very negative
# 821 neutral
# 822 neutral
# 823 neutral
# 824 positive
# 825 neutral
# 826 neutral
# 827 positive
# 828 very positive
# 829 neutral
# 830 negative
# 831 positive
# 832 neutral
# 833 neutral
# 834 neutral
# 835 neutral
# 836 neutral
# 837 positive
# 838 neutral
# 839 negative
# 840 neutral
# 841 neutral
# 842 neutral
# 843 neutral
# 844 negative
# 845 negative
# 846 neutral
# 847 neutral
# 848 very positive
# 849 very positive
# 850 positive
# 851 positive
# 852 positive
# 853 positive
# 854 positive
# 855 positive
# 856 neutral
# 857 neutral
# 858 negative
# 859 neutral
# 860 positive
# 861 neutral
# 862 positive
# 863 very negative
# 864 very negative
# 865 negative
# 866 neutral
# 867 very negative
# 868 negative
# 869 neutral
# 870 neutral
# 871 neutral
# 872 neutral
# 873 neutral
# 874 neutral
# 875 neutral
# 876 neutral
# 877 negative
# 878 neutral
# 879 negative
# 880 negative
# 881 negative
# 882 negative
# 883 neutral
# 884 positive
# 885 neutral
# 886 negative
# 887 neutral
# 888 negative
# 889 negative
# 890 neutral
# 891 very negative
# 892 very negative
# 893 very positive
# 894 negative
# 895 very negative
# 896 very positive
# 897 neutral
# 898 positive
# 899 neutral
# 900 positive
# 901 very positive
# 902 very positive
# 903 positive
# 904 positive
# 905 neutral
# 906 negative
# 907 negative
# 908 negative
# 909 negative
# 910 negative
# 911 negative
# 912 neutral
# 913 positive
# 914 neutral
# 915 neutral
# 916 neutral
# 917 negative
# 918 negative
# 919 very negative
# 920 neutral
# 921 negative
# 922 neutral
# 923 very negative
# 924 negative
# 925 neutral
# 926 negative
# 927 neutral
# 928 neutral
# 929 neutral
# 930 negative
# 931 negative
# 932 negative
# 933 neutral
# 934 very negative
# 935 negative
# 936 negative
# 937 negative
# 938 very negative
# 939 very negative
# 940 very negative
# 941 negative
# 942 very negative
# 943 neutral
# 944 neutral
# 945 neutral
# 946 positive
# 947 positive
# 948 neutral
# 949 positive
# 950 negative
# 951 neutral
# 952 neutral
# 953 very negative
# 954 negative
# 955 positive
# 956 neutral
# 957 negative
# 958 neutral
# 959 neutral
# 960 neutral
# 961 neutral
# 962 neutral
# 963 neutral
# 964 neutral
# 965 neutral
# 966 neutral
# 967 negative
# 968 negative
# 969 neutral
# 970 neutral
# 971 neutral
# 972 neutral
# 973 neutral
# 974 negative
# 975 neutral
# 976 neutral
# 977 neutral
# 978 neutral
# 979 neutral
# 980 neutral
# 981 neutral
# 982 neutral
# 983 neutral
# 984 positive
# 985 neutral
# 986 neutral
# 987 very positive
# 988 neutral
# 989 neutral
# 990 neutral
# 991 neutral
# 992 neutral
# 993 positive
# 994 neutral
# 995 neutral
# 996 neutral
# 997 neutral
# 998 neutral
# 999 neutral
# 1000 positive
# 1001 positive
# 1002 positive
# 1003 neutral
# 1004 neutral
# 1005 neutral
# 1006 negative
# 1007 very negative
# 1008 negative
# 1009 neutral
# 1010 very negative
# 1011 neutral
# 1012 neutral
# 1013 neutral
# 1014 positive
# 1015 negative
# 1016 negative
# 1017 negative
# 1018 neutral
# 1019 positive
# 1020 positive
# 1021 neutral
# 1022 negative
# 1023 negative
# 1024 neutral
# 1025 negative
# 1026 neutral
# 1027 positive
# 1028 neutral
# 1029 negative
# 1030 neutral
# 1031 positive
# 1032 neutral
# 1033 neutral
# 1034 very positive
# 1035 neutral
# 1036 negative
# 1037 negative
# 1038 neutral
# 1039 negative
# 1040 neutral
# 1041 neutral
# 1042 neutral
# 1043 neutral
# 1044 neutral
# 1045 neutral
# 1046 neutral
# 1047 neutral
# 1048 neutral
# 1049 negative
# 1050 neutral
# 1051 negative
# 1052 very negative
# 1053 negative
# 1054 negative
# 1055 positive
# 1056 very positive
# 1057 neutral
# 1058 negative
# 1059 neutral
# 1060 neutral
# 1061 positive
# 1062 positive
# 1063 negative
# 1064 negative
# 1065 very positive
# 1066 positive
# 1067 positive
# 1068 neutral
# 1069 neutral
# 1070 neutral
# 1071 neutral
# 1072 positive
# 1073 neutral
# 1074 neutral
# 1075 neutral
# 1076 neutral
# 1077 neutral
# 1078 negative
# 1079 neutral
# 1080 neutral
# 1081 neutral
# 1082 neutral
# 1083 neutral
# 1084 negative
# 1085 negative
# 1086 neutral
# 1087 negative
# 1088 very negative
# 1089 negative
# 1090 negative
# 1091 neutral
# 1092 neutral
# 1093 neutral
# 1094 very positive
# 1095 neutral
# 1096 neutral
# 1097 neutral
# 1098 neutral
# 1099 neutral
# 1100 neutral
# 1101 neutral
# 1102 neutral
# 1103 neutral
# 1104 positive
# 1105 positive
# 1106 neutral
# 1107 positive
# 1108 neutral
# 1109 neutral
# 1110 neutral
# 1111 negative
# 1112 negative
# 1113 neutral
# 1114 neutral
# 1115 negative
# 1116 negative
# 1117 negative
# 1118 neutral
# 1119 negative
# 1120 neutral
# 1121 neutral
# 1122 very negative
# 1123 neutral
# 1124 neutral
# 1125 neutral
# 1126 neutral
# 1127 neutral
# 1128 negative
# 1129 neutral
# 1130 neutral
# 1131 negative
# 1132 neutral
# 1133 negative
# 1134 neutral
# 1135 neutral
# 1136 neutral
# 1137 neutral
# 1138 neutral
# 1139 negative
# 1140 neutral
# 1141 negative
# 1142 positive
# 1143 negative
# 1144 neutral
# 1145 positive
# 1146 neutral
# 1147 negative
# 1148 neutral
# 1149 negative
# 1150 negative
# 1151 negative
# 1152 neutral
# 1153 neutral
# 1154 neutral
# 1155 neutral
# 1156 negative
# 1157 neutral
# 1158 positive
# 1159 neutral
# 1160 neutral
# 1161 positive
# 1162 neutral
# 1163 positive
# 1164 neutral
# 1165 neutral
# 1166 negative
# 1167 neutral
# 1168 negative
# 1169 neutral
# 1170 neutral
# 1171 neutral
# 1172 negative
# 1173 positive
# 1174 very positive
# 1175 neutral
# 1176 negative
# 1177 neutral
# 1178 positive
# 1179 neutral
# 1180 negative
# 1181 very negative
# 1182 neutral
# 1183 negative
# 1184 neutral
# 1185 neutral
# 1186 neutral
# 1187 negative
# 1188 neutral
# 1189 negative
# 1190 negative
# 1191 very negative
# 1192 neutral
# 1193 positive
# 1194 neutral
# 1195 negative
# 1196 neutral
# 1197 neutral
# 1198 neutral
# 1199 very negative
# 1200 neutral
# 1201 neutral
# 1202 negative
# 1203 neutral
# 1204 neutral
# 1205 neutral
# 1206 neutral
# 1207 neutral
# 1208 positive
# 1209 negative
# 1210 neutral
# 1211 neutral
# 1212 positive
# 1213 neutral
# 1214 negative
# 1215 neutral
# 1216 neutral
# 1217 negative
# 1218 very negative
# 1219 neutral
# 1220 negative
# 1221 negative
# 1222 neutral
# 1223 negative
# 1224 neutral
# 1225 neutral
# 1226 positive
# 1227 neutral
# 1228 neutral
# 1229 neutral
# 1230 positive
# 1231 very positive
# 1232 neutral
# 1233 positive
# 1234 positive
# 1235 negative
# 1236 negative
# 1237 positive
# 1238 positive
# 1239 neutral
# 1240 very negative
# 1241 positive
# 1242 neutral
# 1243 very negative
# 1244 very negative
# 1245 very positive
# 1246 very positive
# 1247 positive
# 1248 positive
# 1249 positive
# 1250 neutral
# 1251 negative
# 1252 very negative
# 1253 negative
# 1254 negative
# 1255 neutral
# 1256 neutral
# 1257 negative
# 1258 neutral
# 1259 positive
# 1260 positive
# 1261 positive
# 1262 positive
# 1263 neutral
# 1264 neutral
# 1265 neutral
# 1266 positive
# 1267 neutral
# 1268 positive
# 1269 neutral
# 1270 neutral
# 1271 neutral
# 1272 neutral
# 1273 neutral
# 1274 neutral
# 1275 neutral
# 1276 neutral
# 1277 neutral
# 1278 negative
# 1279 very negative
# 1280 neutral
# 1281 neutral
# 1282 neutral
# 1283 positive
# 1284 neutral
# 1285 neutral
# 1286 neutral
# 1287 negative
# 1288 negative
# 1289 neutral
# 1290 neutral
# 1291 neutral
# 1292 neutral
# 1293 neutral
# 1294 neutral
# 1295 positive
# 1296 positive
# 1297 positive
# 1298 neutral
# 1299 positive
# 1300 very positive
# 1301 very positive
# 1302 very positive
# 1303 very positive
# 1304 positive
# 1305 neutral
# 1306 neutral
# 1307 neutral
# 1308 neutral
# 1309 neutral
# 1310 very negative
# 1311 very negative
# 1312 very negative
# 1313 positive
# 1314 positive
# 1315 neutral
# 1316 negative
# 1317 positive
# 1318 neutral
# 1319 neutral
# 1320 neutral
# 1321 positive
# 1322 neutral
# 1323 neutral
# 1324 neutral
# 1325 positive
# 1326 neutral
# 1327 neutral
# 1328 neutral
# 1329 negative
# 1330 negative
# 1331 neutral
# 1332 neutral
# 1333 positive
# 1334 neutral
# 1335 negative
# 1336 negative
# 1337 negative
# 1338 positive
# 1339 neutral
# 1340 neutral
# 1341 positive
# 1342 neutral
# 1343 neutral
# 1344 neutral
# 1345 neutral
# 1346 positive
# 1347 positive
# 1348 negative
# 1349 positive
# 1350 positive
# 1351 neutral
# 1352 neutral
# 1353 neutral
# 1354 neutral
# 1355 neutral
# 1356 positive
# 1357 neutral
# 1358 negative
# 1359 neutral
# 1360 positive
# 1361 neutral
# 1362 neutral
# 1363 positive
# 1364 neutral
# 1365 neutral
# 1366 negative
# 1367 negative
# 1368 neutral
# 1369 positive
# 1370 neutral
# 1371 very negative
# 1372 very negative
# 1373 negative
# 1374 neutral
# 1375 negative
# 1376 neutral
# 1377 very negative
# 1378 very negative
# 1379 negative
# 1380 very negative
# 1381 very negative
# 1382 very negative
# 1383 very negative
# 1384 negative
# 1385 very negative
# 1386 negative
# 1387 neutral
# 1388 very positive
# 1389 positive
# 1390 positive
# 1391 positive
# 1392 positive
# 1393 neutral
# 1394 positive
# 1395 neutral
# 1396 neutral
# 1397 neutral
# 1398 neutral
# 1399 positive
# 1400 very negative
# 1401 neutral
# 1402 positive
# 1403 positive
# 1404 negative
# 1405 neutral
# 1406 negative
# 1407 positive
# 1408 neutral
# 1409 positive
# 1410 negative
# 1411 positive
# 1412 neutral
# 1413 neutral
# 1414 neutral
# 1415 very negative
# 1416 negative
# 1417 negative
# 1418 negative
# 1419 positive
# 1420 negative
# 1421 positive
# 1422 positive
# 1423 negative
# 1424 very positive
# 1425 very positive
# 1426 negative
# 1427 negative
# 1428 negative
# 1429 neutral
# 1430 neutral
# 1431 positive
# 1432 positive
# 1433 positive
# 1434 positive
# 1435 positive
# 1436 very positive
# 1437 positive
# 1438 neutral
# 1439 negative
# 1440 negative
# 1441 neutral
# 1442 neutral
# 1443 neutral
# 1444 negative
# 1445 neutral
# 1446 positive
# 1447 positive
# 1448 positive
# 1449 positive
# 1450 neutral
# 1451 positive
# 1452 neutral
# 1453 positive
# 1454 very positive
# 1455 positive
# 1456 very positive
# 1457 neutral
# 1458 neutral
# 1459 negative
# 1460 neutral
# 1461 very negative
# 1462 negative
# 1463 positive
# 1464 positive
# 1465 positive
# 1466 positive
# 1467 negative
# 1468 neutral
# 1469 neutral
# 1470 negative
# 1471 neutral
# 1472 neutral
# 1473 positive
# 1474 positive
# 1475 positive
# 1476 positive
# 1477 negative
# 1478 negative
# 1479 positive
# 1480 negative
# 1481 neutral
# 1482 neutral
# 1483 negative
# 1484 neutral
# 1485 neutral
# 1486 positive
# 1487 positive
# 1488 neutral
# 1489 negative
# 1490 negative
# 1491 negative
# 1492 neutral
# 1493 neutral
# 1494 negative
# 1495 negative
# 1496 positive
# 1497 positive
# 1498 neutral
# 1499 neutral
# 1500 very positive
# 1501 very positive
# 1502 positive
# 1503 positive
# 1504 very positive
# 1505 neutral
# 1506 neutral
# 1507 neutral
# 1508 negative
# 1509 neutral
# 1510 very positive
# 1511 neutral
# 1512 very positive
# 1513 neutral
# 1514 neutral
# 1515 neutral
# 1516 neutral
# 1517 neutral
# 1518 negative
# 1519 neutral
# 1520 neutral
# 1521 neutral
# 1522 negative
# 1523 negative
# 1524 very positive
# 1525 very positive
# 1526 very positive
# 1527 positive
# 1528 positive
# 1529 very positive
# 1530 negative
# 1531 negative
# 1532 negative
# 1533 very positive
# 1534 positive
# 1535 positive
# 1536 positive
# 1537 neutral
# 1538 neutral
# 1539 very negative
# 1540 positive
# 1541 very positive
# 1542 positive
# 1543 neutral
# 1544 positive
# 1545 very positive
# 1546 very positive
# 1547 positive
# 1548 positive
# 1549 neutral
# 1550 neutral
# 1551 neutral
# 1552 neutral
# 1553 very negative
# 1554 very positive
# 1555 very positive
# 1556 very positive
# 1557 positive
# 1558 positive
# 1559 positive
# 1560 positive
# 1561 positive
# 1562 very positive
# 1563 positive
# 1564 very positive
# 1565 positive
# 1566 positive
# 1567 positive
# 1568 negative
# 1569 negative
# 1570 very positive
# 1571 very positive
# 1572 very negative
# 1573 neutral
# 1574 negative
# 1575 negative
# 1576 very positive
# 1577 very positive
# 1578 very positive
# 1579 very positive
# 1580 negative
# 1581 negative
# 1582 negative
# 1583 very positive
# 1584 positive
# 1585 negative
# 1586 negative
# 1587 very negative
# 1588 very positive
# 1589 very positive
# 1590 very positive
# 1591 positive
# 1592 positive
# 1593 positive
# 1594 neutral
# 1595 neutral
# 1596 neutral
# 1597 negative
# 1598 positive
# 1599 positive
# 1600 very negative
# 1601 very negative
# 1602 negative
# 1603 neutral
# 1604 negative
# 1605 neutral
# 1606 negative
# 1607 neutral
# 1608 neutral
# 1609 negative
# 1610 negative
# 1611 negative
# 1612 neutral
# 1613 negative
# 1614 neutral
# 1615 negative
# 1616 negative
# 1617 negative
# 1618 positive
# 1619 positive
# 1620 positive
# 1621 neutral
# 1622 positive
# 1623 positive
# 1624 very negative
# 1625 very negative
# 1626 positive
# 1627 neutral
# 1628 negative
# 1629 negative
# 1630 positive
# 1631 neutral
# 1632 neutral
# 1633 very positive
# 1634 positive
# 1635 positive
# 1636 very positive
# 1637 very positive
# 1638 positive
# 1639 neutral
# 1640 positive
# 1641 neutral
# 1642 neutral
# 1643 very positive
# 1644 very positive
# 1645 very positive
# 1646 neutral
# 1647 neutral
# 1648 positive
# 1649 neutral
# 1650 positive
# 1651 neutral
# 1652 negative
# 1653 neutral
# 1654 positive
# 1655 positive
# 1656 positive
# 1657 negative
# 1658 neutral
# 1659 positive
# 1660 neutral
# 1661 neutral
# 1662 negative
# 1663 very negative
# 1664 very positive
# 1665 very positive
# 1666 negative
# 1667 neutral
# 1668 neutral
# 1669 neutral
# 1670 negative
# 1671 neutral
# 1672 very negative
# 1673 very negative
# 1674 positive
# 1675 neutral
# 1676 very positive
# 1677 negative
# 1678 negative
# 1679 neutral
# 1680 positive
# 1681 positive
# 1682 positive
# 1683 positive
# 1684 positive
# 1685 positive
# 1686 negative
# 1687 negative
# 1688 positive
# 1689 positive
# 1690 very negative
# 1691 very negative
# 1692 positive
# 1693 very positive
# 1694 positive
# 1695 neutral
# 1696 negative
# 1697 negative
# 1698 negative
# 1699 negative
# 1700 negative
# 1701 positive
# 1702 positive
# 1703 negative
# 1704 positive
# 1705 positive
# 1706 positive
# 1707 positive
# 1708 positive
# 1709 positive
# 1710 positive
# 1711 neutral
# 1712 very positive
# 1713 positive
# 1714 neutral
# 1715 neutral
# 1716 positive
# 1717 positive
# 1718 negative
# 1719 very negative
# 1720 negative
# 1721 negative
# 1722 positive
# 1723 neutral
# 1724 neutral
# 1725 positive
# 1726 positive
# 1727 positive
# 1728 negative
# 1729 negative
# 1730 very negative
# 1731 neutral
# 1732 negative
# 1733 very negative
# 1734 very negative
# 1735 negative
# 1736 very negative
# 1737 very negative
# 1738 very negative
# 1739 neutral
# 1740 negative
# 1741 positive
# 1742 positive
# 1743 positive
# 1744 positive
# 1745 positive
# 1746 neutral
# 1747 positive
# 1748 negative
# 1749 very negative
# 1750 positive
# 1751 neutral
# 1752 positive
# 1753 negative
# 1754 positive
# 1755 neutral
# 1756 positive
# 1757 positive
# 1758 neutral
# 1759 neutral
# 1760 neutral
# 1761 neutral
# 1762 positive
# 1763 positive
# 1764 neutral
# 1765 neutral
# 1766 neutral
# 1767 negative
# 1768 neutral
# 1769 negative
# 1770 negative
# 1771 negative
# 1772 neutral
# 1773 negative
# 1774 positive
# 1775 positive
# 1776 positive
# 1777 positive
# 1778 positive
# 1779 positive
# 1780 positive
# 1781 negative
# 1782 neutral
# 1783 neutral
# 1784 positive
# 1785 positive
# 1786 negative
# 1787 negative
# 1788 negative
# 1789 neutral
# 1790 negative
# 1791 positive
# 1792 positive
# 1793 neutral
# 1794 neutral
# 1795 positive
# 1796 negative
# 1797 negative
# 1798 positive
# 1799 very positive
# 1800 very positive
# 1801 positive
# 1802 positive
# 1803 positive
# 1804 very positive
# 1805 positive
# 1806 positive
# 1807 positive
# 1808 neutral
# 1809 negative
# 1810 neutral
# 1811 positive
# 1812 positive
# 1813 neutral
# 1814 very positive
# 1815 positive
# 1816 positive
# 1817 very negative
# 1818 negative
# 1819 very negative
# 1820 neutral
# 1821 positive
# 1822 neutral
# 1823 neutral
# 1824 very positive
# 1825 very positive
# 1826 very positive
# 1827 very positive
# 1828 neutral
# 1829 negative
# 1830 positive
# 1831 very positive
# 1832 negative
# 1833 neutral
# 1834 very positive
# 1835 very positive
# 1836 neutral
# 1837 very negative
# 1838 very negative
# 1839 very negative
# 1840 very negative
# 1841 very negative
# 1842 very positive
# 1843 positive
# 1844 positive
# 1845 positive
# 1846 positive
# 1847 positive
# 1848 positive
# 1849 negative
# 1850 neutral
# 1851 neutral
# 1852 neutral
# 1853 negative
# 1854 positive
# 1855 very positive
# 1856 positive
# 1857 positive
# 1858 positive
# 1859 positive
# 1860 very positive
# 1861 negative
# 1862 negative
# 1863 negative
# 1864 neutral
# 1865 negative
# 1866 negative
# 1867 very positive
# 1868 positive
# 1869 positive
# 1870 positive
# 1871 very positive
# 1872 very positive
# 1873 positive
# 1874 positive
# 1875 positive
# 1876 positive
# 1877 positive
# 1878 neutral
# 1879 positive
# 1880 positive
# 1881 neutral
# 1882 very positive
# 1883 positive
# 1884 positive
# 1885 very positive
# 1886 very positive
# 1887 neutral
# 1888 positive
# 1889 very negative
# 1890 very negative
# 1891 positive
# 1892 positive
# 1893 very positive
# 1894 positive
# 1895 neutral
# 1896 negative
# 1897 very positive
# 1898 very positive
# 1899 positive
# 1900 very positive
# 1901 very positive
# 1902 positive
# 1903 positive
# 1904 very positive
# 1905 very positive
# 1906 very positive
# 1907 very positive
# 1908 very positive
# 1909 very positive
# 1910 neutral
# 1911 neutral
# 1912 neutral
# 1913 positive
# 1914 very positive
# 1915 positive
# 1916 positive
# 1917 positive
# 1918 neutral
# 1919 positive
# 1920 neutral
# 1921 negative
# 1922 neutral
# 1923 negative
# 1924 negative
# 1925 neutral
# 1926 negative
# 1927 negative
# 1928 negative
# 1929 very negative
# 1930 neutral
# 1931 negative
# 1932 negative
# 1933 negative
# 1934 neutral
# 1935 neutral
# 1936 neutral
# 1937 positive
# 1938 positive
# 1939 positive
# 1940 neutral
# 1941 neutral
# 1942 positive
# 1943 neutral
# 1944 very positive
# 1945 negative
# 1946 neutral
# 1947 positive
# 1948 neutral
# 1949 neutral
# 1950 neutral
# 1951 neutral
# 1952 very positive
# 1953 very positive
# 1954 positive
# 1955 very negative
# 1956 neutral
# 1957 neutral
# 1958 positive
# 1959 positive
# 1960 neutral
# 1961 neutral
# 1962 neutral
# 1963 neutral
# 1964 positive
# 1965 positive
# 1966 positive
# 1967 negative
# 1968 negative
# 1969 positive
# 1970 very positive
# 1971 neutral
# 1972 positive
# 1973 neutral
# 1974 positive
# 1975 positive
# 1976 neutral
# 1977 positive
# 1978 neutral
# 1979 neutral
# 1980 positive
# 1981 neutral
# 1982 very positive
# 1983 very positive
# 1984 neutral
# 1985 neutral
# 1986 neutral
# 1987 neutral
# 1988 neutral
# 1989 negative
# 1990 negative
# 1991 neutral
# 1992 neutral
# 1993 positive
# 1994 negative
# 1995 negative
# 1996 positive
# 1997 neutral
# 1998 neutral
# 1999 neutral
# 2000 neutral
# 2001 neutral
# 2002 neutral
# 2003 neutral
# 2004 negative
# 2005 negative
# 2006 neutral
# 2007 neutral
# 2008 positive
# 2009 negative
# 2010 negative
# 2011 negative
# 2012 negative
# 2013 neutral
# 2014 neutral
# 2015 positive
# 2016 very positive
# 2017 very positive
# 2018 negative
# 2019 neutral
# 2020 negative
# 2021 negative
# 2022 neutral
# 2023 neutral
# 2024 neutral
# 2025 positive
# 2026 neutral
# 2027 neutral
# 2028 neutral
# 2029 neutral
# 2030 neutral
# 2031 negative
# 2032 negative
# 2033 neutral
# 2034 positive
# 2035 positive
# 2036 neutral
# 2037 negative
# 2038 neutral
# 2039 neutral
# 2040 neutral
# 2041 very positive
# 2042 positive
# 2043 very positive
# 2044 very positive
# 2045 neutral
# 2046 neutral
# 2047 neutral
# 2048 positive
# 2049 negative
# 2050 neutral
# 2051 negative
# 2052 negative
# 2053 neutral
# 2054 negative
# 2055 positive
# 2056 negative
# 2057 neutral
# 2058 neutral
# 2059 neutral
# 2060 neutral
# 2061 positive
# 2062 very positive
# 2063 positive
# 2064 very positive
# 2065 neutral
# 2066 very negative
# 2067 neutral
# 2068 negative
# 2069 very negative
# 2070 negative
# 2071 very negative
# 2072 neutral
# 2073 neutral
# 2074 neutral
# 2075 negative
# 2076 neutral
# 2077 very negative
# 2078 negative
# 2079 negative
# 2080 negative
# 2081 positive
# 2082 positive
# 2083 negative
# 2084 positive
# 2085 very positive
# 2086 negative
# 2087 negative
# 2088 neutral
# 2089 neutral
# 2090 negative
# 2091 very negative
# 2092 positive
# 2093 positive
# 2094 positive
# 2095 positive
# 2096 positive
# 2097 very positive
# 2098 neutral
# 2099 negative
# 2100 very negative
# 2101 negative
# 2102 negative
# 2103 very negative
# 2104 very positive
# 2105 positive
# 2106 negative
# 2107 positive
# 2108 very positive
# 2109 neutral
# 2110 negative
# 2111 negative
# 2112 neutral
# 2113 negative
# 2114 negative
# 2115 negative
# 2116 negative
# 2117 negative
# 2118 negative
# 2119 very positive
# 2120 very positive
# 2121 negative
# 2122 very negative
# 2123 positive
# 2124 negative
# 2125 negative
# 2126 negative
# 2127 very negative
# 2128 neutral
# 2129 neutral
# 2130 very negative
# 2131 very negative
# 2132 very negative
# 2133 neutral
# 2134 very positive
# 2135 positive
# 2136 neutral
# 2137 very positive
# 2138 positive
# 2139 positive
# 2140 very positive
# 2141 positive
# 2142 very positive
# 2143 very positive
# 2144 very positive
# 2145 very negative
# 2146 very negative
# 2147 positive
# 2148 positive
# 2149 positive
# 2150 positive
# 2151 positive
# 2152 neutral
# 2153 positive
# 2154 positive
# 2155 positive
# 2156 neutral
# 2157 negative
# 2158 neutral
# 2159 very positive
# 2160 positive
# 2161 positive
# 2162 negative
# 2163 negative
# 2164 neutral
# 2165 neutral
# 2166 neutral
# 2167 neutral
# 2168 negative
# 2169 neutral
# 2170 positive
# 2171 positive
# 2172 neutral
# 2173 positive
# 2174 positive
# 2175 positive
# 2176 positive
# 2177 positive
# 2178 positive
# 2179 positive
# 2180 positive
# 2181 positive
# 2182 very positive
# 2183 very positive
# 2184 positive
# 2185 positive
# 2186 positive
# 2187 positive
# 2188 neutral
# 2189 neutral
# 2190 neutral
# 2191 positive
# 2192 positive
# 2193 positive
# 2194 neutral
# 2195 positive
# 2196 negative
# 2197 neutral
# 2198 positive
# 2199 positive
# 2200 positive
# 2201 neutral
# 2202 negative
# 2203 neutral
# 2204 neutral
# 2205 positive
# 2206 positive
# 2207 negative
# 2208 negative
# 2209 negative
# 2210 very positive
# 2211 neutral
# 2212 positive
# 2213 very positive
# 2214 negative
# 2215 very positive
# 2216 very positive
# 2217 very negative
# 2218 neutral
# 2219 neutral
# 2220 negative
# 2221 neutral
# 2222 very negative
# 2223 very negative
# 2224 very negative
# 2225 negative
# 2226 neutral
# 2227 neutral
# 2228 very positive
# 2229 neutral
# 2230 negative
# 2231 positive
# 2232 very negative
# 2233 negative
# 2234 positive
# 2235 positive
# 2236 very positive
# 2237 neutral
# 2238 positive
# 2239 positive
# 2240 positive
# 2241 negative
# 2242 positive
# 2243 positive
# 2244 positive
# 2245 positive
# 2246 very positive
# 2247 neutral
# 2248 negative
# 2249 negative
# 2250 positive
# 2251 positive
# 2252 positive
# 2253 positive
# 2254 positive
# 2255 very positive
# 2256 neutral
# 2257 very positive
# 2258 negative
# 2259 negative
# 2260 negative
# 2261 negative
# 2262 negative
# 2263 neutral
# 2264 very negative
# 2265 negative
# 2266 very negative
# 2267 neutral
# 2268 very negative
# 2269 negative
# 2270 neutral
# 2271 negative
# 2272 negative
# 2273 very negative
# 2274 negative
# 2275 very negative
# 2276 very negative
# 2277 positive
# 2278 very positive
# 2279 neutral
# 2280 neutral
# 2281 positive
# 2282 positive
# 2283 positive
# 2284 very positive
# 2285 positive
# 2286 very positive
# 2287 neutral
# 2288 very negative
# 2289 very negative
# 2290 positive
# 2291 neutral
# 2292 neutral
# 2293 neutral
# 2294 positive
# 2295 very positive
# 2296 neutral
# 2297 neutral
# 2298 neutral
# 2299 neutral
# 2300 positive
# 2301 positive
# 2302 neutral
# 2303 neutral
# 2304 positive
# 2305 negative
# 2306 neutral
# 2307 neutral
# 2308 neutral
# 2309 neutral
# 2310 neutral
# 2311 positive
# 2312 neutral
# 2313 positive
# 2314 very positive
# 2315 very positive
# 2316 neutral
# 2317 neutral
# 2318 positive
# 2319 positive
# 2320 negative
# 2321 negative
# 2322 neutral
# 2323 positive
# 2324 neutral
# 2325 negative
# 2326 very negative
# 2327 negative
# 2328 negative
# 2329 very negative
# 2330 very negative
# 2331 very negative
# 2332 neutral
# 2333 neutral
# 2334 neutral
# 2335 neutral
# 2336 negative
# 2337 negative
# 2338 neutral
# 2339 neutral
# 2340 negative
# 2341 very negative
# 2342 positive
# 2343 neutral
# 2344 negative
# 2345 neutral
# 2346 positive
# 2347 neutral
# 2348 neutral
# 2349 very negative
# 2350 neutral
# 2351 neutral
# 2352 neutral
# 2353 neutral
# 2354 neutral
# 2355 neutral
# 2356 neutral
# 2357 neutral
# 2358 neutral
# 2359 negative
# 2360 very positive
# 2361 very positive
# 2362 neutral
# 2363 negative
# 2364 neutral
# 2365 neutral
# 2366 neutral
# 2367 positive
# 2368 neutral
# 2369 neutral
# 2370 negative
# 2371 negative
# 2372 neutral
# 2373 positive
# 2374 neutral
# 2375 negative
# 2376 neutral
# 2377 neutral
# 2378 negative
# 2379 neutral
# 2380 positive
# 2381 neutral
# 2382 positive
# 2383 neutral
# 2384 positive
# 2385 very positive
# 2386 positive
# 2387 negative
# 2388 negative
# 2389 positive
# 2390 neutral
# 2391 positive
# 2392 positive
# 2393 positive
# 2394 negative
# 2395 neutral
# 2396 neutral
# 2397 very positive
# 2398 positive
# 2399 neutral
# 2400 neutral
# 2401 neutral
# 2402 neutral
# 2403 positive
# 2404 positive
# 2405 neutral
# 2406 neutral
# 2407 neutral
# 2408 very negative
# 2409 very positive
# 2410 positive
# 2411 positive
# 2412 positive
# 2413 positive
# 2414 positive
# 2415 neutral
# 2416 positive
# 2417 neutral
# 2418 very positive
# 2419 negative
# 2420 neutral
# 2421 negative
# 2422 positive
# 2423 neutral
# 2424 positive
# 2425 very positive
# 2426 positive
# 2427 very positive
# 2428 positive
# 2429 neutral
# 2430 neutral
# 2431 neutral
# 2432 positive
# 2433 positive
# 2434 positive
# 2435 positive
# 2436 positive
# 2437 neutral
# 2438 positive
# 2439 negative
# 2440 neutral
# 2441 positive
# 2442 negative
# 2443 neutral
# 2444 neutral
# 2445 neutral
# 2446 neutral
# 2447 neutral
# 2448 very positive
# 2449 negative
# 2450 negative
# 2451 negative
# 2452 negative
# 2453 neutral
# 2454 neutral
# 2455 neutral
# 2456 negative
# 2457 neutral
# 2458 negative
# 2459 very negative
# 2460 neutral
# 2461 positive
# 2462 neutral
# 2463 positive
# 2464 positive
# 2465 positive
# 2466 positive
# 2467 very positive
# 2468 neutral
# 2469 neutral
# 2470 neutral
# 2471 positive
# 2472 neutral
# 2473 positive
# 2474 positive
# 2475 very positive
# 2476 positive
# 2477 very positive
# 2478 neutral
# 2479 positive
# 2480 positive
# 2481 positive
# 2482 positive
# 2483 neutral
# 2484 neutral
# 2485 negative
# 2486 negative
# 2487 very positive
# 2488 negative
# 2489 very negative
# 2490 positive
# 2491 neutral
# 2492 neutral
# 2493 neutral
# 2494 very negative
# 2495 neutral
# 2496 neutral
# 2497 neutral
# 2498 neutral
# 2499 neutral
# 2500 neutral
# 2501 neutral
# 2502 very negative
# 2503 neutral
# 2504 neutral
# 2505 neutral
# 2506 negative
# 2507 negative
# 2508 very positive
# 2509 very positive
# 2510 negative
# 2511 negative
# 2512 neutral
# 2513 positive
# 2514 very positive
# 2515 positive
# 2516 positive
# 2517 neutral
# 2518 positive
# 2519 positive
# 2520 positive
# 2521 neutral
# 2522 neutral
# 2523 negative
# 2524 positive
# 2525 positive
# 2526 neutral
# 2527 negative
# 2528 very negative
# 2529 negative
# 2530 negative
# 2531 very positive
# 2532 neutral
# 2533 neutral
# 2534 positive
# 2535 neutral
# 2536 negative
# 2537 very negative
# 2538 negative
# 2539 negative
# 2540 negative
# 2541 negative
# 2542 very negative
# 2543 very negative
# 2544 neutral
# 2545 very negative
# 2546 very negative
# 2547 very negative
# 2548 negative
# 2549 negative
# 2550 neutral
# 2551 neutral
# 2552 neutral
# 2553 negative
# 2554 negative
# 2555 negative
# 2556 negative
# 2557 neutral
# 2558 negative
# 2559 neutral
# 2560 neutral
# 2561 neutral
# 2562 positive
# 2563 neutral
# 2564 negative
# 2565 negative
# 2566 negative
# 2567 negative
# 2568 negative
# 2569 neutral
# 2570 positive
# 2571 negative
# 2572 negative
# 2573 very negative
# 2574 neutral
# 2575 very negative
# 2576 very negative
# 2577 negative
# 2578 neutral
# 2579 neutral
# 2580 neutral
# 2581 neutral
# 2582 negative
# 2583 negative
# 2584 neutral
# 2585 very positive
# 2586 positive
# 2587 very positive
# 2588 very positive
# 2589 positive
# 2590 negative
# 2591 positive
# 2592 positive
# 2593 positive
# 2594 very positive
# 2595 positive
# 2596 neutral
# 2597 neutral
# 2598 positive
# 2599 positive
# 2600 positive
# 2601 positive
# 2602 very positive
# 2603 positive
# 2604 positive
# 2605 neutral
# 2606 positive
# 2607 very positive
# 2608 positive
# 2609 positive
# 2610 positive
# 2611 neutral
# 2612 neutral
# 2613 very positive
# 2614 neutral
# 2615 positive
# 2616 positive
# 2617 neutral
# 2618 neutral
# 2619 very positive
# 2620 very positive
# 2621 positive
# 2622 neutral
# 2623 neutral
# 2624 neutral
# 2625 negative
# 2626 neutral
# 2627 negative
# 2628 very positive
# 2629 positive
# 2630 negative
# 2631 negative
# 2632 negative
# 2633 negative
# 2634 positive
# 2635 positive
# 2636 positive
# 2637 positive
# 2638 positive
# 2639 positive
# 2640 neutral
# 2641 negative
# 2642 negative
# 2643 negative
# 2644 very negative
# 2645 very negative
# 2646 negative
# 2647 neutral
# 2648 neutral
# 2649 very positive
# 2650 very positive
# 2651 neutral
# 2652 positive
# 2653 neutral
# 2654 neutral
# 2655 very negative
# 2656 positive
# 2657 neutral
# 2658 neutral
# 2659 neutral
# 2660 neutral
# 2661 neutral
# 2662 neutral
# 2663 very positive
# 2664 neutral
# 2665 negative
# 2666 very negative
# 2667 very negative
# 2668 neutral
# 2669 negative
# 2670 negative
# 2671 positive
# 2672 neutral
# 2673 negative
# 2674 neutral
# 2675 neutral
# 2676 positive
# 2677 positive
# 2678 negative
# 2679 neutral
# 2680 neutral
# 2681 negative
# 2682 neutral
# 2683 neutral
# 2684 neutral
# 2685 neutral
# 2686 negative
# 2687 very negative
# 2688 neutral
# 2689 negative
# 2690 very positive
# 2691 neutral
# 2692 very positive
# 2693 positive
# 2694 neutral
# 2695 neutral
# 2696 negative
# 2697 negative
# 2698 negative
# 2699 negative
# 2700 neutral
# 2701 neutral
# 2702 very positive
# 2703 very positive
# 2704 positive
# 2705 neutral
# 2706 neutral
# 2707 positive
# 2708 negative
# 2709 neutral
# 2710 neutral
# 2711 negative
# 2712 neutral
# 2713 neutral
# 2714 neutral
# 2715 negative
# 2716 negative
# 2717 negative
# 2718 negative
# 2719 negative
# 2720 neutral
# 2721 positive
# 2722 positive
# 2723 neutral
# 2724 very positive
# 2725 positive
# 2726 neutral
# 2727 negative
# 2728 very negative
# 2729 neutral
# 2730 neutral
# 2731 neutral
# 2732 positive
# 2733 neutral
# 2734 neutral
# 2735 neutral
# 2736 neutral
# 2737 positive
# 2738 positive
# 2739 positive
# 2740 negative
# 2741 negative
# 2742 neutral
# 2743 negative
# 2744 negative
# 2745 positive
# 2746 neutral
# 2747 neutral
# 2748 neutral
# 2749 neutral
# 2750 neutral
# 2751 neutral
# 2752 very negative
# 2753 neutral
# 2754 positive
# 2755 neutral
# 2756 neutral
# 2757 neutral
# 2758 neutral
# 2759 positive
# 2760 positive
# 2761 negative
# 2762 neutral
# 2763 very negative
# 2764 negative
# 2765 very positive
# 2766 positive
# 2767 negative
# 2768 neutral
# 2769 negative
# 2770 positive
# 2771 positive
# 2772 neutral
# 2773 negative
# 2774 neutral
# 2775 positive
# 2776 positive
# 2777 positive
# 2778 positive
# 2779 positive
# 2780 positive
# 2781 very positive
# 2782 very positive
# 2783 very positive
# 2784 positive
# 2785 positive
# 2786 very positive
# 2787 very positive
# 2788 neutral
# 2789 positive
# 2790 neutral
# 2791 positive
# 2792 very positive
# 2793 very positive
# 2794 positive
# 2795 positive
# 2796 neutral
# 2797 very positive
# 2798 positive
# 2799 very positive
# 2800 neutral
# 2801 positive
# 2802 positive
# 2803 positive
# 2804 negative
# 2805 neutral
# 2806 negative
# 2807 negative
# 2808 negative
# 2809 negative
# 2810 neutral
# 2811 neutral
# 2812 neutral
# 2813 neutral
# 2814 neutral
# 2815 neutral
# 2816 neutral
# 2817 positive
# 2818 neutral
# 2819 positive
# 2820 neutral
# 2821 neutral
# 2822 positive
# 2823 negative
# 2824 positive
# 2825 very positive
# 2826 positive
# 2827 neutral
# 2828 neutral
# 2829 positive
# 2830 positive
# 2831 positive
# 2832 very positive
# 2833 positive
# 2834 neutral
# 2835 neutral
# 2836 positive
# 2837 neutral
# 2838 positive
# 2839 positive
# 2840 neutral
# 2841 very positive
# 2842 negative
# 2843 negative
# 2844 neutral
# 2845 negative
# 2846 negative
# 2847 positive
# 2848 positive
# 2849 positive
# 2850 positive
# 2851 neutral
# 2852 neutral
# 2853 neutral
# 2854 positive
# 2855 positive
# 2856 positive
# 2857 negative
# 2858 negative
# 2859 neutral
# 2860 positive
# 2861 very positive
# 2862 positive
# 2863 neutral
# 2864 positive
# 2865 positive
# 2866 positive
# 2867 neutral
# 2868 neutral
# 2869 positive
# 2870 positive
# 2871 neutral
# 2872 neutral
# 2873 positive
# 2874 neutral
# 2875 negative
# 2876 negative
# 2877 negative
# 2878 negative
# 2879 negative
# 2880 negative
# 2881 neutral
# 2882 neutral
# 2883 neutral
# 2884 positive
# 2885 neutral
# 2886 negative
# 2887 negative
# 2888 positive
# 2889 very positive
# 2890 negative
# 2891 negative
# 2892 negative
# 2893 negative
# 2894 very negative
# 2895 negative
# 2896 very negative
# 2897 very negative
# 2898 very negative
# 2899 very negative
# 2900 positive
# 2901 very positive
# 2902 negative
# 2903 very negative
# 2904 positive
# 2905 neutral
# 2906 negative
# 2907 negative
# 2908 very negative
# 2909 negative
# 2910 negative
# 2911 very negative
# 2912 negative
# 2913 positive
# 2914 positive
# 2915 very positive
# 2916 positive
# 2917 neutral
# 2918 positive
# 2919 negative
# 2920 negative
# 2921 neutral
# 2922 negative
# 2923 negative
# 2924 very positive
# 2925 negative
# 2926 negative
# 2927 neutral
# 2928 very negative
# 2929 very negative
# 2930 neutral
# 2931 very negative
# 2932 very negative
# 2933 neutral
# 2934 neutral
# 2935 negative
# 2936 negative
# 2937 neutral
# 2938 very negative
# 2939 very negative
# 2940 neutral
# 2941 neutral
# 2942 neutral
# 2943 neutral
# 2944 neutral
# 2945 neutral
# 2946 neutral
# 2947 neutral
# 2948 very positive
# 2949 positive
# 2950 negative
# 2951 neutral
# 2952 neutral
# 2953 neutral
# 2954 neutral
# 2955 neutral
# 2956 neutral
# 2957 neutral
# 2958 positive
# 2959 positive
# 2960 negative
# 2961 negative
# 2962 negative
# 2963 positive
# 2964 positive
# 2965 neutral
# 2966 negative
# 2967 negative
# 2968 positive
# 2969 very positive
# 2970 neutral
# 2971 neutral
# 2972 neutral
# 2973 negative
# 2974 neutral
# 2975 negative
# 2976 negative
# 2977 negative
# 2978 negative
# 2979 neutral
# 2980 negative
# 2981 neutral
# 2982 neutral
# 2983 neutral
# 2984 negative
# 2985 neutral
# 2986 neutral
# 2987 negative
# 2988 neutral
# 2989 neutral
# 2990 neutral
# 2991 neutral
# 2992 very negative
# 2993 neutral
# 2994 neutral
# 2995 neutral
# 2996 positive
# 2997 positive
# 2998 positive
# 2999 neutral
# 3000 positive
# 3001 negative
# 3002 very positive
# 3003 neutral
# 3004 positive
# 3005 positive
# 3006 negative
# 3007 neutral
# 3008 neutral
# 3009 positive
# 3010 positive
# 3011 positive
# 3012 neutral
# 3013 neutral
# 3014 very positive
# 3015 very positive
# 3016 neutral
# 3017 neutral
# 3018 neutral
# 3019 positive
# 3020 positive
# 3021 negative
# 3022 neutral
# 3023 neutral
# 3024 neutral
# 3025 neutral
# 3026 neutral
# 3027 neutral
# 3028 neutral
# 3029 neutral
# 3030 negative
# 3031 positive
# 3032 neutral
# 3033 neutral
# 3034 negative
# 3035 negative
# 3036 neutral
# 3037 neutral
# 3038 neutral
# 3039 negative
# 3040 neutral
# 3041 neutral
# 3042 positive
# 3043 very positive
# 3044 negative
# 3045 positive
# 3046 very positive
# 3047 very negative
# 3048 negative
# 3049 neutral
# 3050 negative
# 3051 positive
# 3052 negative
# 3053 negative
# 3054 negative
# 3055 neutral
# 3056 positive
# 3057 negative
# 3058 very negative
# 3059 very negative
# 3060 very negative
# 3061 very negative
# 3062 negative
# 3063 negative
# 3064 neutral
# 3065 negative
# 3066 neutral
# 3067 negative
# 3068 negative
# 3069 very negative
# 3070 very negative
# 3071 very negative
# 3072 negative
# 3073 very negative
# 3074 neutral
# 3075 negative
# 3076 very negative
# 3077 negative
# 3078 negative
# 3079 negative
# 3080 neutral
# 3081 neutral
# 3082 very negative
# 3083 negative
# 3084 very negative
# 3085 very negative
# 3086 very negative
# 3087 negative
# 3088 neutral
# 3089 neutral
# 3090 negative
# 3091 negative
# 3092 negative
# 3093 very negative
# 3094 negative
# 3095 neutral
# 3096 negative
# 3097 neutral
# 3098 positive
# 3099 very negative
# 3100 negative
# 3101 negative
# 3102 neutral
# 3103 negative
# 3104 negative
# 3105 very negative
# 3106 negative
# 3107 negative
# 3108 negative
# 3109 very negative
# 3110 negative
# 3111 negative
# 3112 neutral
# 3113 neutral
# 3114 negative
# 3115 very negative
# 3116 negative
# 3117 negative
# 3118 neutral
# 3119 neutral
# 3120 negative
# 3121 neutral
# 3122 neutral
# 3123 neutral
# 3124 neutral
# 3125 neutral
# 3126 neutral
# 3127 neutral
# 3128 positive
# 3129 neutral
# 3130 neutral
# 3131 neutral
# 3132 negative
# 3133 neutral
# 3134 positive
# 3135 positive
# 3136 positive
# 3137 neutral
# 3138 neutral
# 3139 neutral
# 3140 negative
# 3141 very positive
# 3142 very negative
# 3143 very negative
# 3144 negative
# 3145 negative
# 3146 negative
# 3147 positive
# 3148 positive
# 3149 positive
# 3150 neutral
# 3151 very negative
# 3152 neutral
# 3153 neutral
# 3154 neutral
# 3155 neutral
# 3156 neutral
# 3157 negative
# 3158 neutral
# 3159 neutral
# 3160 negative
# 3161 negative
# 3162 negative
# 3163 negative
# 3164 negative
# 3165 negative
# 3166 negative
# 3167 negative
# 3168 negative
# 3169 neutral
# 3170 positive
# 3171 neutral
# 3172 negative
# 3173 negative
# 3174 positive
# 3175 very positive
# 3176 very positive
# 3177 positive
# 3178 positive
# 3179 negative
# 3180 neutral
# 3181 positive
# 3182 neutral
# 3183 negative
# 3184 positive
# 3185 negative
# 3186 negative
# 3187 neutral
# 3188 negative
# 3189 positive
# 3190 positive
# 3191 positive
# 3192 neutral
# 3193 neutral
# 3194 neutral
# 3195 negative
# 3196 negative
# 3197 negative
# 3198 very negative
# 3199 neutral
# 3200 neutral
# 3201 neutral
# 3202 positive
# 3203 negative
# 3204 negative
# 3205 negative
# 3206 neutral
# 3207 positive
# 3208 positive
# 3209 neutral
# 3210 neutral
# 3211 neutral
# 3212 positive
# 3213 positive
# 3214 positive
# 3215 neutral
# 3216 neutral
# 3217 very negative
# 3218 very negative
# 3219 negative
# 3220 negative
# 3221 very negative
# 3222 very negative
# 3223 neutral
# 3224 neutral
# 3225 neutral
# 3226 neutral
# 3227 negative
# 3228 positive
# 3229 neutral
# 3230 neutral
# 3231 negative
# 3232 neutral
# 3233 neutral
# 3234 negative
# 3235 neutral
# 3236 positive
# 3237 positive
# 3238 positive
# 3239 positive
# 3240 neutral
# 3241 very negative
# 3242 negative
# 3243 neutral
# 3244 neutral
# 3245 negative
# 3246 neutral
# 3247 negative
# 3248 very negative
# 3249 neutral
# 3250 neutral
# 3251 neutral
# 3252 neutral
# 3253 neutral
# 3254 negative
# 3255 neutral
# 3256 positive
# 3257 negative
# 3258 positive
# 3259 positive
# 3260 positive
# 3261 positive
# 3262 very positive
# 3263 positive
# 3264 very positive
# 3265 very positive
# 3266 positive
# 3267 neutral
# 3268 neutral
# 3269 positive
# 3270 very positive
# 3271 negative
# 3272 negative
# 3273 neutral
# 3274 neutral
# 3275 positive
# 3276 neutral
# 3277 positive
# 3278 positive
# 3279 positive
# 3280 neutral
# 3281 negative
# 3282 neutral
# 3283 negative
# 3284 neutral
# 3285 negative
# 3286 negative
# 3287 negative
# 3288 neutral
# 3289 neutral
# 3290 negative
# 3291 negative
# 3292 neutral
# 3293 negative
# 3294 negative
# 3295 neutral
# 3296 neutral
# 3297 neutral
# ...
# 111710 neutral
# 111711 negative
# 111712 neutral
# 111713 negative
# 111714 positive
# 111715 positive
# 111716 positive
# 111717 neutral
# 111718 negative
# 111719 neutral
# 111720 very negative
# 111721 negative
# 111722 positive
# 111723 neutral
# 111724 positive
# 111725 positive
# 111726 positive
# 111727 neutral
# 111728 very negative
# 111729 negative
# 111730 positive
# 111731 neutral
# 111732 negative
# 111733 negative
# 111734 neutral
# 111735 neutral
# 111736 negative
# 111737 negative
# 111738 negative
# 111739 positive
# 111740 neutral
# 111741 neutral
# 111742 neutral
# 111743 neutral
# 111744 neutral
# 111745 neutral
# 111746 neutral
# 111747 positive
# 111748 positive
# 111749 neutral
# 111750 positive
# 111751 positive
# 111752 neutral
# 111753 neutral
# 111754 neutral
# 111755 neutral
# 111756 positive
# 111757 neutral
# 111758 neutral
# 111759 positive
# 111760 positive
# 111761 positive
# 111762 positive
# 111763 positive
# 111764 neutral
# 111765 negative
# 111766 negative
# 111767 very negative
# 111768 very negative
# 111769 negative
# 111770 negative
# 111771 neutral
# 111772 negative
# 111773 neutral
# 111774 neutral
# 111775 negative
# 111776 neutral
# 111777 very negative
# 111778 very negative
# 111779 negative
# 111780 negative
# 111781 neutral
# 111782 neutral
# 111783 positive
# 111784 negative
# 111785 neutral
# 111786 neutral
# 111787 neutral
# 111788 neutral
# 111789 very negative
# 111790 negative
# 111791 very negative
# 111792 neutral
# 111793 neutral
# 111794 negative
# 111795 negative
# 111796 negative
# 111797 neutral
# 111798 negative
# 111799 negative
# 111800 positive
# 111801 neutral
# 111802 neutral
# 111803 neutral
# 111804 neutral
# 111805 neutral
# 111806 neutral
# 111807 positive
# 111808 negative
# 111809 positive
# 111810 neutral
# 111811 neutral
# 111812 very positive
# 111813 negative
# 111814 negative
# 111815 negative
# 111816 neutral
# 111817 negative
# 111818 very negative
# 111819 negative
# 111820 negative
# 111821 negative
# 111822 negative
# 111823 negative
# 111824 negative
# 111825 positive
# 111826 very negative
# 111827 neutral
# 111828 negative
# 111829 very negative
# 111830 negative
# 111831 very negative
# 111832 negative
# 111833 negative
# 111834 negative
# 111835 very negative
# 111836 negative
# 111837 negative
# 111838 negative
# 111839 negative
# 111840 very negative
# 111841 negative
# 111842 negative
# 111843 very negative
# 111844 very negative
# 111845 negative
# 111846 very negative
# 111847 very negative
# 111848 negative
# 111849 very negative
# 111850 very negative
# 111851 negative
# 111852 very negative
# 111853 positive
# 111854 positive
# 111855 negative
# 111856 negative
# 111857 neutral
# 111858 neutral
# 111859 negative
# 111860 negative
# 111861 negative
# 111862 negative
# 111863 negative
# 111864 negative
# 111865 neutral
# 111866 negative
# 111867 negative
# 111868 negative
# 111869 negative
# 111870 neutral
# 111871 negative
# 111872 negative
# 111873 negative
# 111874 negative
# 111875 negative
# 111876 neutral
# 111877 neutral
# 111878 negative
# 111879 negative
# 111880 negative
# 111881 very negative
# 111882 very negative
# 111883 very negative
# 111884 negative
# 111885 neutral
# 111886 negative
# 111887 negative
# 111888 negative
# 111889 negative
# 111890 negative
# 111891 neutral
# 111892 neutral
# 111893 neutral
# 111894 negative
# 111895 neutral
# 111896 neutral
# 111897 negative
# 111898 negative
# 111899 negative
# 111900 negative
# 111901 negative
# 111902 neutral
# 111903 negative
# 111904 neutral
# 111905 negative
# 111906 negative
# 111907 negative
# 111908 negative
# 111909 neutral
# 111910 neutral
# 111911 very positive
# 111912 neutral
# 111913 positive
# 111914 neutral
# 111915 neutral
# 111916 positive
# 111917 positive
# 111918 positive
# 111919 neutral
# 111920 negative
# 111921 negative
# 111922 negative
# 111923 neutral
# 111924 neutral
# 111925 neutral
# 111926 neutral
# 111927 neutral
# 111928 neutral
# 111929 negative
# 111930 negative
# 111931 positive
# 111932 positive
# 111933 positive
# 111934 negative
# 111935 neutral
# 111936 neutral
# 111937 neutral
# 111938 neutral
# 111939 neutral
# 111940 negative
# 111941 negative
# 111942 negative
# 111943 negative
# 111944 negative
# 111945 very negative
# 111946 neutral
# 111947 negative
# 111948 neutral
# 111949 neutral
# 111950 neutral
# 111951 positive
# 111952 neutral
# 111953 positive
# 111954 positive
# 111955 neutral
# 111956 neutral
# 111957 neutral
# 111958 neutral
# 111959 neutral
# 111960 neutral
# 111961 neutral
# 111962 very positive
# 111963 neutral
# 111964 neutral
# 111965 neutral
# 111966 neutral
# 111967 positive
# 111968 neutral
# 111969 neutral
# 111970 negative
# 111971 neutral
# 111972 neutral
# 111973 neutral
# 111974 neutral
# 111975 neutral
# 111976 neutral
# 111977 neutral
# 111978 positive
# 111979 neutral
# 111980 neutral
# 111981 neutral
# 111982 neutral
# 111983 neutral
# 111984 negative
# 111985 neutral
# 111986 neutral
# 111987 positive
# 111988 neutral
# 111989 positive
# 111990 positive
# 111991 positive
# 111992 neutral
# 111993 neutral
# 111994 positive
# 111995 neutral
# 111996 neutral
# 111997 neutral
# 111998 neutral
# 111999 neutral
# 112000 positive
# 112001 positive
# 112002 neutral
# 112003 neutral
# 112004 neutral
# 112005 positive
# 112006 neutral
# 112007 positive
# 112008 neutral
# 112009 neutral
# 112010 neutral
# 112011 positive
# 112012 positive
# 112013 neutral
# 112014 neutral
# 112015 neutral
# 112016 positive
# 112017 neutral
# 112018 neutral
# 112019 neutral
# 112020 positive
# 112021 positive
# 112022 positive
# 112023 neutral
# 112024 neutral
# 112025 neutral
# 112026 neutral
# 112027 positive
# 112028 neutral
# 112029 negative
# 112030 positive
# 112031 neutral
# 112032 positive
# 112033 neutral
# 112034 neutral
# 112035 neutral
# 112036 neutral
# 112037 neutral
# 112038 neutral
# 112039 neutral
# 112040 negative
# 112041 neutral
# 112042 neutral
# 112043 positive
# 112044 positive
# 112045 neutral
# 112046 neutral
# 112047 positive
# 112048 positive
# 112049 positive
# 112050 positive
# 112051 neutral
# 112052 neutral
# 112053 neutral
# 112054 neutral
# 112055 neutral
# 112056 neutral
# 112057 neutral
# 112058 positive
# 112059 positive
# 112060 neutral
# 112061 neutral
# 112062 neutral
# 112063 neutral
# 112064 neutral
# 112065 positive
# 112066 neutral
# 112067 neutral
# 112068 positive
# 112069 neutral
# 112070 neutral
# 112071 neutral
# 112072 neutral
# 112073 neutral
# 112074 very positive
# 112075 neutral
# 112076 neutral
# 112077 neutral
# 112078 positive
# 112079 negative
# 112080 neutral
# 112081 neutral
# 112082 neutral
# 112083 positive
# 112084 positive
# 112085 positive
# 112086 neutral
# 112087 positive
# 112088 positive
# 112089 positive
# 112090 positive
# 112091 positive
# 112092 positive
# 112093 positive
# 112094 positive
# 112095 neutral
# 112096 neutral
# 112097 negative
# 112098 positive
# 112099 negative
# 112100 neutral
# 112101 negative
# 112102 positive
# 112103 neutral
# 112104 neutral
# 112105 neutral
# 112106 neutral
# 112107 neutral
# 112108 neutral
# 112109 positive
# 112110 neutral
# 112111 neutral
# 112112 neutral
# 112113 neutral
# 112114 neutral
# 112115 neutral
# 112116 negative
# 112117 neutral
# 112118 neutral
# 112119 negative
# 112120 neutral
# 112121 neutral
# 112122 positive
# 112123 neutral
# 112124 very positive
# 112125 neutral
# 112126 neutral
# 112127 positive
# 112128 very positive
# 112129 neutral
# 112130 negative
# 112131 positive
# 112132 positive
# 112133 neutral
# 112134 positive
# 112135 neutral
# 112136 positive
# 112137 neutral
# 112138 neutral
# 112139 positive
# 112140 neutral
# 112141 neutral
# 112142 neutral
# 112143 neutral
# 112144 neutral
# 112145 very positive
# 112146 neutral
# 112147 positive
# 112148 positive
# 112149 positive
# 112150 positive
# 112151 very positive
# 112152 positive
# 112153 very positive
# 112154 positive
# 112155 very positive
# 112156 very positive
# 112157 positive
# 112158 very positive
# 112159 positive
# 112160 positive
# 112161 very positive
# 112162 positive
# 112163 positive
# 112164 very positive
# 112165 very positive
# 112166 positive
# 112167 positive
# 112168 positive
# 112169 positive
# 112170 very positive
# 112171 very positive
# 112172 positive
# 112173 neutral
# 112174 positive
# 112175 neutral
# 112176 positive
# 112177 neutral
# 112178 neutral
# 112179 neutral
# 112180 neutral
# 112181 neutral
# 112182 neutral
# 112183 positive
# 112184 negative
# 112185 neutral
# 112186 neutral
# 112187 neutral
# 112188 neutral
# 112189 neutral
# 112190 neutral
# 112191 neutral
# 112192 positive
# 112193 positive
# 112194 neutral
# 112195 neutral
# 112196 neutral
# 112197 positive
# 112198 positive
# 112199 neutral
# 112200 neutral
# 112201 neutral
# 112202 neutral
# 112203 neutral
# 112204 neutral
# 112205 neutral
# 112206 positive
# 112207 positive
# 112208 neutral
# 112209 negative
# 112210 neutral
# 112211 neutral
# 112212 neutral
# 112213 neutral
# 112214 neutral
# 112215 very negative
# 112216 negative
# 112217 positive
# 112218 negative
# 112219 negative
# 112220 positive
# 112221 positive
# 112222 neutral
# 112223 negative
# 112224 neutral
# 112225 negative
# 112226 neutral
# 112227 negative
# 112228 neutral
# 112229 positive
# 112230 positive
# 112231 positive
# 112232 neutral
# 112233 negative
# 112234 neutral
# 112235 neutral
# 112236 positive
# 112237 negative
# 112238 very negative
# 112239 negative
# 112240 negative
# 112241 negative
# 112242 neutral
# 112243 neutral
# 112244 neutral
# 112245 neutral
# 112246 negative
# 112247 negative
# 112248 neutral
# 112249 neutral
# 112250 negative
# 112251 positive
# 112252 neutral
# 112253 negative
# 112254 neutral
# 112255 very negative
# 112256 negative
# 112257 positive
# 112258 very positive
# 112259 very positive
# 112260 positive
# 112261 positive
# 112262 positive
# 112263 neutral
# 112264 negative
# 112265 negative
# 112266 positive
# 112267 positive
# 112268 positive
# 112269 neutral
# 112270 positive
# 112271 very positive
# 112272 positive
# 112273 positive
# 112274 neutral
# 112275 positive
# 112276 positive
# 112277 negative
# 112278 neutral
# 112279 positive
# 112280 positive
# 112281 positive
# 112282 neutral
# 112283 positive
# 112284 positive
# 112285 neutral
# 112286 positive
# 112287 positive
# 112288 neutral
# 112289 positive
# 112290 positive
# 112291 positive
# 112292 positive
# 112293 positive
# 112294 negative
# 112295 neutral
# 112296 neutral
# 112297 very positive
# 112298 positive
# 112299 positive
# 112300 negative
# 112301 neutral
# 112302 neutral
# 112303 very negative
# 112304 negative
# 112305 negative
# 112306 negative
# 112307 negative
# 112308 negative
# 112309 negative
# 112310 very negative
# 112311 negative
# 112312 negative
# 112313 negative
# 112314 negative
# 112315 positive
# 112316 negative
# 112317 negative
# 112318 neutral
# 112319 negative
# 112320 negative
# 112321 negative
# 112322 negative
# 112323 neutral
# 112324 negative
# 112325 negative
# 112326 negative
# 112327 negative
# 112328 negative
# 112329 very negative
# 112330 neutral
# 112331 neutral
# 112332 negative
# 112333 negative
# 112334 neutral
# 112335 neutral
# 112336 neutral
# 112337 negative
# 112338 positive
# 112339 neutral
# 112340 neutral
# 112341 very negative
# 112342 negative
# 112343 neutral
# 112344 neutral
# 112345 negative
# 112346 negative
# 112347 positive
# 112348 neutral
# 112349 neutral
# 112350 positive
# 112351 positive
# 112352 positive
# 112353 neutral
# 112354 neutral
# 112355 neutral
# 112356 negative
# 112357 very positive
# 112358 positive
# 112359 neutral
# 112360 negative
# 112361 neutral
# 112362 neutral
# 112363 neutral
# 112364 neutral
# 112365 negative
# 112366 neutral
# 112367 neutral
# 112368 negative
# 112369 neutral
# 112370 negative
# 112371 neutral
# 112372 negative
# 112373 negative
# 112374 negative
# 112375 neutral
# 112376 negative
# 112377 neutral
# 112378 negative
# 112379 negative
# 112380 neutral
# 112381 neutral
# 112382 negative
# 112383 negative
# 112384 negative
# 112385 negative
# 112386 very negative
# 112387 neutral
# 112388 negative
# 112389 neutral
# 112390 positive
# 112391 positive
# 112392 neutral
# 112393 positive
# 112394 positive
# 112395 neutral
# 112396 neutral
# 112397 neutral
# 112398 positive
# 112399 neutral
# 112400 neutral
# 112401 positive
# 112402 positive
# 112403 positive
# 112404 neutral
# 112405 very positive
# 112406 very positive
# 112407 positive
# 112408 very positive
# 112409 very positive
# 112410 positive
# 112411 very positive
# 112412 very positive
# 112413 very positive
# 112414 positive
# 112415 very positive
# 112416 very positive
# 112417 neutral
# 112418 very positive
# 112419 very positive
# 112420 positive
# 112421 positive
# 112422 neutral
# 112423 neutral
# 112424 positive
# 112425 neutral
# 112426 positive
# 112427 neutral
# 112428 positive
# 112429 positive
# 112430 very positive
# 112431 positive
# 112432 very positive
# 112433 positive
# 112434 very positive
# 112435 positive
# 112436 very positive
# 112437 very positive
# 112438 positive
# 112439 very positive
# 112440 very positive
# 112441 positive
# 112442 positive
# 112443 very positive
# 112444 positive
# 112445 neutral
# 112446 very positive
# 112447 positive
# 112448 very positive
# 112449 very positive
# 112450 very positive
# 112451 positive
# 112452 very positive
# 112453 positive
# 112454 positive
# 112455 positive
# 112456 positive
# 112457 very positive
# 112458 very positive
# 112459 positive
# 112460 positive
# 112461 positive
# 112462 positive
# 112463 neutral
# 112464 negative
# 112465 neutral
# 112466 positive
# 112467 positive
# 112468 positive
# 112469 neutral
# 112470 neutral
# 112471 neutral
# 112472 neutral
# 112473 positive
# 112474 positive
# 112475 very positive
# 112476 positive
# 112477 positive
# 112478 neutral
# 112479 neutral
# 112480 neutral
# 112481 positive
# 112482 very positive
# 112483 neutral
# 112484 very positive
# 112485 positive
# 112486 neutral
# 112487 neutral
# 112488 positive
# 112489 positive
# 112490 positive
# 112491 very positive
# 112492 very positive
# 112493 very positive
# 112494 positive
# 112495 neutral
# 112496 positive
# 112497 neutral
# 112498 neutral
# 112499 neutral
# 112500 neutral
# 112501 positive
# 112502 negative
# 112503 negative
# 112504 very positive
# 112505 positive
# 112506 neutral
# 112507 positive
# 112508 negative
# 112509 neutral
# 112510 positive
# 112511 positive
# 112512 positive
# 112513 positive
# 112514 very positive
# 112515 very positive
# 112516 positive
# 112517 positive
# 112518 positive
# 112519 positive
# 112520 neutral
# 112521 neutral
# 112522 neutral
# 112523 positive
# 112524 positive
# 112525 very positive
# 112526 neutral
# 112527 positive
# 112528 neutral
# 112529 neutral
# 112530 neutral
# 112531 negative
# 112532 very negative
# 112533 neutral
# 112534 neutral
# 112535 neutral
# 112536 neutral
# 112537 negative
# 112538 negative
# 112539 negative
# 112540 very negative
# 112541 neutral
# 112542 neutral
# 112543 neutral
# 112544 negative
# 112545 neutral
# 112546 negative
# 112547 neutral
# 112548 neutral
# 112549 negative
# 112550 neutral
# 112551 neutral
# 112552 very negative
# 112553 neutral
# 112554 neutral
# 112555 neutral
# 112556 neutral
# 112557 neutral
# 112558 neutral
# 112559 neutral
# 112560 neutral
# 112561 positive
# 112562 negative
# 112563 neutral
# 112564 neutral
# 112565 neutral
# 112566 neutral
# 112567 negative
# 112568 negative
# 112569 neutral
# 112570 neutral
# 112571 neutral
# 112572 neutral
# 112573 neutral
# 112574 neutral
# 112575 neutral
# 112576 neutral
# 112577 positive
# 112578 negative
# 112579 neutral
# 112580 neutral
# 112581 neutral
# 112582 negative
# 112583
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f73203f3e0f5> in <module>
#      23     if (movie_data["sentiment"][i]>0.8) and (movie_data["sentiment"][i]<=1):
#      24         movie_data["label"][i]=labels[4]
# ---> 25     print(i,movie_data["label"][i],)
#      26
#      27 print(movie_data.head())
#
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# c:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# c:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     414                                  copy_threshold=self.copy_threshold)
#     415             data.group = group
# --> 416         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     417
#     418     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
#split phrase datasets

x_train, x_test, y_train, y_test = train_test_split(movie_data, y, test_size=0.3, random_state=1) # 70% training and 30% test
print(x_train.shape,x_test.shape,y_train.ravel().shape)

# %%
#naive bayes


clf2 = LogisticRegression( solver='lbfgs')
clf2.fit(x_train,y)
print(clf2.score(x_train,y_train))
print(clf2.score(x_test,y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5e057df42b1b> in <module>
#       1 clf2 = LogisticRegression( solver='lbfgs')
# ----> 2 clf2.fit(x_train,y)
#       3 print(clf2.score(x_train,y_train))
#       4 print(clf2.score(x_test,y_test))
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1340             _dtype = [np.float64, np.float32]
#    1341
# -> 1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
#    1344                                    accept_large_sparse=solver != 'liblinear')
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     793         raise ValueError("y cannot be None")
#     794
# --> 795     X = check_array(X, accept_sparse=accept_sparse,
#     796                     accept_large_sparse=accept_large_sparse,
#     797                     dtype=dtype, order=order, copy=copy,
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1779
#    1780     def __array__(self, dtype=None) -> np.ndarray:
# -> 1781         return np.asarray(self._values, dtype=dtype)
#    1782
#    1783     def __array_wrap__(self, result, context=None):
#
# c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Despite its dry wit and compassion , the film suffers from a philosophical emptiness and maddeningly sedate pacing .'

# %%
#random forest

# %%
#nn
